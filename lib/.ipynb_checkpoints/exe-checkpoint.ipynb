# %%
from SelectObjects import SelectHalosByMass
from SelectObjects import SelectVoidsByMass
from SelectObjects import SelectVoidsByXYZ

# %%
halodir = "/home/alexander/surp2022/SURPProject2022/cat/halo/"
voiddir = "/home/alexander/surp2022/SURPProject2022/cat/void/default/"
voidConvDir = "/home/alexander/surp2022/SURPProject2022/cat/void/converged/"
haloConvDir = "/home/alexander/surp2022/SURPProject2022/cat/halo/converged/"
voidConvCentDir = "/home/alexander/surp2022/SURPProject2022/cat/void/converged/centered/"
voidConvCentRandDir = "/home/alexander/surp2022/SURPProject2022/cat/void/converged/centered/rand/"

#SelectHalosByMass(halodir + 'Trial_PP_halo_catalog_2048Mpc_n512_1_25_10.npy', 1e+13, 1e+15, autoCenter=False, export_file=True, include_plot=False, generate_randoms=False, seed=0, export_rand_file=False, fileAppendix="converged", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
#SelectHalosByMass(halodir + 'Trial_PP_halo_catalog_2048Mpc_n1024_1_25_10.npy', 1e+13, 1e+15, autoCenter=False, export_file=True, include_plot=False, generate_randoms=False, seed=0, export_rand_file=False, fileAppendix="converged", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
#SelectHalosByMass(halodir + 'Trial_PP_halo_catalog_2048Mpc_n2048_1_25_10.npy', 1e+13, 1e+15, autoCenter=False, export_file=True, include_plot=False, generate_randoms=False, seed=0, export_rand_file=False, fileAppendix="converged", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
#SelectHalosByMass(halodir + 'Trial_PP_halo_catalog_2048Mpc_n4096_1_25_10.npy', 1e+13, 1e+15, autoCenter=False, export_file=True, include_plot=False, generate_randoms=False, seed=0, export_rand_file=False, fileAppendix="converged", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)

# %%
import numpy as np
a = np.load(halodir + "Trial_PP_halo_catalog_2048Mpc_n512_1_25_10.npy")

# %%
from ObjectInfo import HaloInfo

HaloInfo(halodir + 'Trial_PP_halo_catalog_2048Mpc_n512_1_25_10.npy', autoCenter=False, boxLength=2048)
HaloInfo(halodir + 'Trial_PP_halo_catalog_2048Mpc_n1024_1_25_10.npy', autoCenter=False, boxLength=2048)
HaloInfo(halodir + 'Trial_PP_halo_catalog_2048Mpc_n2048_1_25_10.npy', autoCenter=False, boxLength=2048)
HaloInfo(halodir + 'Trial_PP_halo_catalog_2048Mpc_n4096_1_25_10.npy', autoCenter=False, boxLength=2048)
# Out:
# Shape of array: (266708, 4)
#
#
# x minimum: -696.3059
# x maximum: 696.3119
# y minimum: -696.314
# y maximum: 696.3193
# z minimum: -696.3134
# z maximum: 696.3161
#
#
# x box size: 1392.6178
# y box size: 1392.6333
# z box size: 1392.6295
#
#
# minimum mass: 6.803886e+11
# maximum mass: 3.130174e+15
# maximum/minimum mass: 4600.568
# Shape of array: (2086795, 4)
#
#
# x minimum: -696.3197
# x maximum: 696.3197
# y minimum: -696.3197
# y maximum: 696.3195
# z minimum: -696.32
# z maximum: 696.31726
#
#
# x box size: 1392.6394
# y box size: 1392.6392
# z box size: 1392.6372
#
#
# minimum mass: 6.800181e+11
# maximum mass: 3.607175e+15
# maximum/minimum mass: 5304.5283
# Shape of array: (8274917, 4)
#
#
# x minimum: -696.32
# x maximum: 696.31976
# y minimum: -696.32
# y maximum: 696.31976
# z minimum: -696.32
# z maximum: 696.3196
#
#
# x box size: 1392.6398
# y box size: 1392.6398
# z box size: 1392.6396
#
#
# minimum mass: 6.800001e+11
# maximum mass: 4.368673e+15
# ...

# %%
from ObjectInfo import HaloInfo

HaloInfo(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n512_1_25_10_converged.npy', autoCenter=False, boxLength=2048)
HaloInfo(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n1024_1_25_10_converged.npy', autoCenter=False, boxLength=2048)
HaloInfo(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n2048_1_25_10_converged.npy', autoCenter=False, boxLength=2048)
HaloInfo(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n4096_1_25_10_converged.npy', autoCenter=False, boxLength=2048)
# Out:
# Shape of array: (259941, 4)
#
#
# x minimum: -696.3059
# x maximum: 696.3119
# y minimum: -696.314
# y maximum: 696.3193
# z minimum: -696.3134
# z maximum: 696.3161
#
#
# x box size: 1392.6178
# y box size: 1392.6333
# z box size: 1392.6295
#
#
# minimum mass: 1.000063e+13
# maximum mass: 9.991352e+14
# maximum/minimum mass: 99.90725
# Shape of array: (819878, 4)
#
#
# x minimum: -696.3195
# x maximum: 696.3168
# y minimum: -696.31903
# y maximum: 696.3195
# z minimum: -696.32
# z maximum: 696.3166
#
#
# x box size: 1392.6362
# y box size: 1392.6385
# z box size: 1392.6366
#
#
# minimum mass: 1.000001e+13
# maximum mass: 9.993998e+14
# maximum/minimum mass: 99.93991
# Shape of array: (914495, 4)
#
#
# x minimum: -696.31946
# x maximum: 696.31793
# y minimum: -696.3182
# y maximum: 696.31934
# z minimum: -696.31934
# z maximum: 696.3168
#
#
# x box size: 1392.6375
# y box size: 1392.6375
# z box size: 1392.6361
#
#
# minimum mass: 1.000000e+13
# maximum mass: 9.995510e+14
# ...

# %%
from ObjectInfo import VoidInfo

VoidInfo(voidConvDir+"2048Mpc_n512_convzobov-Voids_cat.txt",autoCenter=True)
VoidInfo(voidConvDir+"2048Mpc_n1024_convzobov-Voids_cat.txt",autoCenter=True)
VoidInfo(voidConvDir+"2048Mpc_n2048_convzobov-Voids_cat.txt",autoCenter=True)
VoidInfo(voidConvDir+"2048Mpc_n4096_convzobov-Voids_cat.txt",autoCenter=True)
# Out:
# Shape of array: (2876, 9)
#
#
# x minimum: -347.729842
# x maximum: 1044.450639
# y minimum: -347.91247200000004
# y maximum: 1044.431051
# z minimum: -348.13931
# z maximum: 1044.07483
#
#
# x box size: 1392.1804809999999
# y box size: 1392.343523
# z box size: 1392.21414
#
#
# minimum radius: 18.691
# maximum radius: 131.317
# maximum/minimum radius: 7.0256808089454825
#
#
# minimum delta_avg: -0.374993
# maximum delta_avg: 1.652317
# maximum/minimum delta_avg: -4.4062609168704485
#
#
# The mean density is: 8.685451636698969e-27 kg / m3
# minimum density: 5.428468071098312e-27 kg / m3
# maximum density: 2.30365710286945e-26 kg / m3
# maximum/minimum density: 4.2436596710116845
#
#
# minimum mass: 4.2162722676618597e+46 kg
# maximum mass: 6.729188307703143e+48 kg
# maximum/minimum mass: 159.60042142712064
# Shape of array: (6877, 9)
#
#
# x minimum: -348.114757
# x maximum: 1044.372471
# y minimum: -347.96153000000004
# y maximum: 1044.3487269999998
# z minimum: -348.158317
# ...

# %%
from LoadCat import LoadHaloCat
from LoadCat import LoadVoidCat
import matplotlib.pyplot as plt
import astropy.units as u

voids_512,x_min_void,x_max_void,y_min_void,y_max_void,z_min_void,z_max_void,radius_min_void,radius_max_void,delta_avg_min_void,delta_avg_max_void,mean_density,void_density,void_mass_512,density_min_void,density_max_void,mass_min_void,mass_max_void=LoadVoidCat(voiddir+'Trial_PP_void_catalog_2048Mpc_n512_1_25_10_centered.npy')
voids_1024,x_min_void,x_max_void,y_min_void,y_max_void,z_min_void,z_max_void,radius_min_void,radius_max_void,delta_avg_min_void,delta_avg_max_void,mean_density,void_density,void_mass_1024,density_min_void,density_max_void,mass_min_void,mass_max_void=LoadVoidCat(voiddir+'Trial_PP_void_catalog_2048Mpc_n1024_1_25_10_centered.npy')
voids_2048,x_min_void,x_max_void,y_min_void,y_max_void,z_min_void,z_max_void,radius_min_void,radius_max_void,delta_avg_min_void,delta_avg_max_void,mean_density,void_density,void_mass_2048,density_min_void,density_max_void,mass_min_void,mass_max_void=LoadVoidCat(voiddir+'Trial_PP_void_catalog_2048Mpc_n2048_1_25_10_centered.npy')
voids_4096,x_min_void,x_max_void,y_min_void,y_max_void,z_min_void,z_max_void,radius_min_void,radius_max_void,delta_avg_min_void,delta_avg_max_void,mean_density,void_density,void_mass_4096,density_min_void,density_max_void,mass_min_void,mass_max_void=LoadVoidCat(voiddir+'Trial_PP_void_catalog_2048Mpc_n4096_1_25_10.npy')

voids_512_conv,x_min_void,x_max_void,y_min_void,y_max_void,z_min_void,z_max_void,radius_min_void,radius_max_void,delta_avg_min_void,delta_avg_max_void,mean_density,void_density,void_mass_512_conv,density_min_void,density_max_void,mass_min_void,mass_max_void=LoadVoidCat(voidConvDir+'2048Mpc_n512_convzobov-Voids_cat.txt')
voids_1024_conv,x_min_void,x_max_void,y_min_void,y_max_void,z_min_void,z_max_void,radius_min_void,radius_max_void,delta_avg_min_void,delta_avg_max_void,mean_density,void_density,void_mass_1024_conv,density_min_void,density_max_void,mass_min_void,mass_max_void=LoadVoidCat(voidConvDir+'2048Mpc_n1024_convzobov-Voids_cat.txt')
voids_2048_conv,x_min_void,x_max_void,y_min_void,y_max_void,z_min_void,z_max_void,radius_min_void,radius_max_void,delta_avg_min_void,delta_avg_max_void,mean_density,void_density,void_mass_2048_conv,density_min_void,density_max_void,mass_min_void,mass_max_void=LoadVoidCat(voidConvDir+'2048Mpc_n2048_convzobov-Voids_cat.txt')
voids_4096_conv,x_min_void,x_max_void,y_min_void,y_max_void,z_min_void,z_max_void,radius_min_void,radius_max_void,delta_avg_min_void,delta_avg_max_void,mean_density,void_density,void_mass_4096_conv,density_min_void,density_max_void,mass_min_void,mass_max_void=LoadVoidCat(voidConvDir+'2048Mpc_n4096_convzobov-Voids_cat.txt')

print(np.min(void_mass_512_conv))
print(np.min(void_mass_1024_conv))
print(np.min(void_mass_2048_conv))
print(np.min(void_mass_4096_conv))
print(np.max(void_mass_512_conv))
print(np.max(void_mass_1024_conv))
print(np.max(void_mass_2048_conv))
print(np.max(void_mass_4096_conv))

bins_mass_void=np.geomspace(2e+14, 1e+19, num=40)

plt.figure(figsize=(8,6), dpi=200)

void_mass_512 = void_mass_512.to(u.Msun)
void_mass_512=void_mass_512/u.Msun

void_mass_1024 = void_mass_1024.to(u.Msun)
void_mass_1024=void_mass_1024/u.Msun

void_mass_2048 = void_mass_2048.to(u.Msun)
void_mass_2048=void_mass_2048/u.Msun

void_mass_4096 = void_mass_4096.to(u.Msun)
void_mass_4096=void_mass_4096/u.Msun



void_mass_512_conv = void_mass_512_conv.to(u.Msun)
void_mass_512_conv = void_mass_512_conv/u.Msun

void_mass_1024_conv = void_mass_1024_conv.to(u.Msun)
void_mass_1024_conv = void_mass_1024_conv/u.Msun

void_mass_2048_conv = void_mass_2048_conv.to(u.Msun)
void_mass_2048_conv = void_mass_2048_conv/u.Msun

void_mass_4096_conv = void_mass_4096_conv.to(u.Msun)
void_mass_4096_conv = void_mass_4096_conv/u.Msun

#plt.hist(void_mass_512, bins=bins_mass_void, log=True, label="512 Resolution", density=False, histtype="step", lw=3, alpha=0.5, color="blue")
#plt.hist(void_mass_1024, bins=bins_mass_void, log=True, label="1024 Resolution", density=False, histtype="step", lw=3, alpha=0.5, color="blue")
#plt.hist(void_mass_2048, bins=bins_mass_void, log=True, label="2048 Resolution", density=False, histtype="step", lw=3, alpha=0.5, color="blue")
#plt.hist(void_mass_4096, bins=bins_mass_void, log=True, label="4096 Resolution", density=False, histtype="step", lw=3, alpha=0.5, color="blue")

plt.hist(void_mass_512_conv, bins=bins_mass_void, log=True, label="512 Resolution, Converged", density=False, histtype="step", lw=3, alpha=0.5)
plt.hist(void_mass_1024_conv, bins=bins_mass_void, log=True, label="1024 Resolution, Converged", density=False, histtype="step", lw=3, alpha=0.5)
plt.hist(void_mass_2048_conv, bins=bins_mass_void, log=True, label="2048 Resolution, Converged", density=False, histtype="step", lw=3, alpha=0.5)
plt.hist(void_mass_4096_conv, bins=bins_mass_void, log=True, label="4096 Resolution, Converged", density=False, histtype="step", lw=3, alpha=0.5)
plt.xscale('log')

plt.legend(loc = "lower left")



#min = 1e+46
#max = 7e+48
# Out:
# 4.2162722676618597e+46 kg
# 1.336629793818692e+46 kg
# 1.1983305631262168e+46 kg
# 1.1388963434647024e+46 kg
# 6.729188307703143e+48 kg
# 2.3901667994150008e+48 kg
# 2.967393964335013e+48 kg
# 2.744999732054848e+48 kg

# %%
#Split Halos into 3 logarithic bins between 1e+13 and 1e+15

HaloBins = np.geomspace(1e+13, 1e+15, num=3)
print(HaloBins)

VoidBins = np.geomspace(1e+46, 7e+48, num=3)
print(VoidBins)

print(HaloBins[0])
print(HaloBins[1])
# Out:
# [1.e+13 1.e+14 1.e+15]
# [1.00000000e+46 2.64575131e+47 7.00000000e+48]
# 10000000000000.0
# 100000000000000.0

# %%
SelectHalosByMass(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n512_1_25_10_converged.npy', HaloBins[0], HaloBins[1], autoCenter=False, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n512_bin1", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectHalosByMass(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n1024_1_25_10_converged.npy', HaloBins[0], HaloBins[1], autoCenter=False, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n1024_bin1", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectHalosByMass(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n2048_1_25_10_converged.npy', HaloBins[0], HaloBins[1], autoCenter=False, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n2048_bin1", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectHalosByMass(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n4096_1_25_10_converged.npy', HaloBins[0], HaloBins[1], autoCenter=False, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n4096_bin1", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)

SelectHalosByMass(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n512_1_25_10_converged.npy', HaloBins[1], HaloBins[2], autoCenter=False, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n512_bin2", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectHalosByMass(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n1024_1_25_10_converged.npy', HaloBins[1], HaloBins[2], autoCenter=False, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n1024_bin2", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectHalosByMass(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n2048_1_25_10_converged.npy', HaloBins[1], HaloBins[2], autoCenter=False, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n2048_bin2", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectHalosByMass(haloConvDir + 'Trial_PP_halo_catalog_2048Mpc_n4096_1_25_10_converged.npy', HaloBins[1], HaloBins[2], autoCenter=False, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n4096_bin2", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
# Out:
# Shape of array: (196216, 4)
#
#
# minimum mass: 10000627000000.0
# maximum mass: 99997630000000.0
#
#
# Mass Selected Halo Catalogue Saved as /home/alexander/surp2022/SURPProject2022/cat/halo/converged/Trial_PP_halo_catalog_2048Mpc_n512_1_25_10_converged_massmin_10000000000000.0_massmax_100000000000000.0.npy
# Shape of random array: (196216, 3)
# Random Halo Catalogue Saved as RandomHalos_2048n512_bin1.npy
# Shape of array: (750122, 4)
#
#
# minimum mass: 10000007000000.0
# maximum mass: 99999455000000.0
#
#
# Mass Selected Halo Catalogue Saved as /home/alexander/surp2022/SURPProject2022/cat/halo/converged/Trial_PP_halo_catalog_2048Mpc_n1024_1_25_10_converged_massmin_10000000000000.0_massmax_100000000000000.0.npy
# Shape of random array: (750122, 3)
# Random Halo Catalogue Saved as RandomHalos_2048n1024_bin1.npy
# Shape of array: (844409, 4)
#
#
# minimum mass: 10000001000000.0
# maximum mass: 99997530000000.0
#
#
# ...

# %%
SelectVoidsByMass(voidConvDir + '2048Mpc_n512_convzobov-Voids_cat.txt', 1e+45, 1e+60, autoCenter=True, boxLength = 2048, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n512", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectVoidsByMass(voidConvDir + '2048Mpc_n1024_convzobov-Voids_cat.txt', 1e+45, 1e+60, autoCenter=True, boxLength = 2048, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n1024", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectVoidsByMass(voidConvDir + '2048Mpc_n2048_convzobov-Voids_cat.txt', 1e+45, 1e+60, autoCenter=True, boxLength = 2048, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n2048", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
SelectVoidsByMass(voidConvDir + '2048Mpc_n4096_convzobov-Voids_cat.txt', 1e+45, 1e+60, autoCenter=True, boxLength = 2048, export_file=True, include_plot=False, generate_randoms=True, seed=0, export_rand_file=True, fileAppendix="2048n4096", include_rand_plot=False, pointSize=0.05, title="Mass Cut Halo 1", graphSize=20, axisLabelSize=20, axisTickSize=15, titleSize=45)
# Out:
# Shape of array: (2876, 9)
#
#
# minimum mass: 4.2162722676618597e+46
# maximum mass: 6.729188307703143e+48
#
#
# Mass Selected Void Catalogue Saved as /home/alexander/surp2022/SURPProject2022/cat/void/converged/2048Mpc_n512_convzobov-Voids_cat_massmin_1e+45_massmax_1e+60.npy
# Shape of random array: (2876, 3)
# Random Void Catalogue Saved as RandomVoids_2048n512.npy
# Shape of array: (6877, 9)
#
#
# minimum mass: 1.336629793818692e+46
# maximum mass: 2.3901667994150008e+48
#
#
# Mass Selected Void Catalogue Saved as /home/alexander/surp2022/SURPProject2022/cat/void/converged/2048Mpc_n1024_convzobov-Voids_cat_massmin_1e+45_massmax_1e+60.npy
# Shape of random array: (6877, 3)
# Random Void Catalogue Saved as RandomVoids_2048n1024.npy
# Shape of array: (7446, 9)
#
#
# minimum mass: 1.1983305631262168e+46
# maximum mass: 2.967393964335013e+48
#
#
# ...

# %%
from ObjectInfo import VoidInfo

VoidInfo(voidConvCentDir+"2048Mpc_n512_convzobov-Voids_cat_centered.npy",autoCenter=False)
VoidInfo(voidConvCentDir+"2048Mpc_n1024_convzobov-Voids_cat_centered.npy",autoCenter=False)
VoidInfo(voidConvCentDir+"2048Mpc_n2048_convzobov-Voids_cat_centered.npy",autoCenter=False)
VoidInfo(voidConvCentDir+"2048Mpc_n4096_convzobov-Voids_cat_centered.npy",autoCenter=False)
# Out:
# Shape of array: (2876, 9)
#
#
# x minimum: -695.889842
# x maximum: 696.2906389999999
# y minimum: -696.0724720000001
# y maximum: 696.271051
# z minimum: -696.2993100000001
# z maximum: 695.91483
#
#
# x box size: 1392.1804809999999
# y box size: 1392.343523
# z box size: 1392.21414
#
#
# minimum radius: 18.691
# maximum radius: 131.317
# maximum/minimum radius: 7.0256808089454825
#
#
# minimum delta_avg: -0.374993
# maximum delta_avg: 1.652317
# maximum/minimum delta_avg: -4.4062609168704485
#
#
# The mean density is: 8.685451636698969e-27 kg / m3
# minimum density: 5.428468071098312e-27 kg / m3
# maximum density: 2.30365710286945e-26 kg / m3
# maximum/minimum density: 4.2436596710116845
#
#
# minimum mass: 4.2162722676618597e+46 kg
# maximum mass: 6.729188307703143e+48 kg
# maximum/minimum mass: 159.60042142712064
# Shape of array: (6877, 9)
#
#
# x minimum: -696.274757
# x maximum: 696.2124709999999
# y minimum: -696.12153
# y maximum: 696.1887269999999
# ...

# %%
from ObjectInfo import VoidInfo

VoidInfo(voidConvCentRandDir+"RandomVoids_2048n512.npy",autoCenter=False)
VoidInfo(voidConvCentRandDir+"RandomVoids_2048n512.npy",autoCenter=False)
VoidInfo(voidConvCentRandDir+"RandomVoids_2048n512.npy",autoCenter=False)
VoidInfo(voidConvCentRandDir+"RandomVoids_2048n512.npy",autoCenter=False)
# Out:
# Shape of array: (2876, 3)
#
#
# x minimum: -695.787239087769
# x maximum: 696.2405463173329
# y minimum: -695.9715972151018
# y maximum: 696.2106410542374
# z minimum: -696.0899473328445
# z maximum: 695.8841341573604
#
#
# x box size: 1392.027785405102
# y box size: 1392.1822382693392
# z box size: 1391.974081490205
#
#
# minimum radius: nan
# maximum radius: nan
# maximum/minimum radius: nan
#
#
# minimum delta_avg: nan
# maximum delta_avg: nan
# maximum/minimum delta_avg: nan
#
#
# The mean density is: nan
# minimum density: nan
# maximum density: nan
# maximum/minimum density: nan
#
#
# minimum mass: nan
# maximum mass: nan
# maximum/minimum mass: nan
# Shape of array: (2876, 3)
#
#
# x minimum: -695.787239087769
# x maximum: 696.2405463173329
# y minimum: -695.9715972151018
# y maximum: 696.2106410542374
# z minimum: -696.0899473328445
# z maximum: 695.8841341573604
#
#
# x box size: 1392.027785405102
# y box size: 1392.1822382693392
# z box size: 1391.974081490205
#
#
# ...

# %%
resultsDir = "/home/alexander/surp2022/SURPProject2022/results/corrfunc/2048RestTestConv/"

corr_voidhalo_bin1_2048n512 = np.load(resultsDir + "corr_voidhalo_bin1_2048n512.npy")
corr_voidhalo_bin2_2048n512 = np.load(resultsDir + "corr_voidhalo_bin2_2048n512.npy")

corr_voidhalo_bin1_2048n1024 = np.load(resultsDir + "corr_voidhalo_bin1_2048n1024.npy")
corr_voidhalo_bin2_2048n1024 = np.load(resultsDir + "corr_voidhalo_bin2_2048n1024.npy")

corr_voidhalo_bin1_2048n2048 = np.load(resultsDir + "corr_voidhalo_bin1_2048n2048.npy")
corr_voidhalo_bin2_2048n2048 = np.load(resultsDir + "corr_voidhalo_bin2_2048n2048.npy")

corr_voidhalo_bin1_2048n4096 = np.load(resultsDir + "corr_voidhalo_bin1_2048n4096.npy")
corr_voidhalo_bin2_2048n4096 = np.load(resultsDir + "corr_voidhalo_bin2_2048n4096.npy")


#corr_halohalo_bin1_2048n512 = np.load(resultsDir + "corr_halohalo_bin1_2048n512.npy")
corr_halohalo_bin2_2048n512 = np.load(resultsDir + "corr_halohalo_bin2_2048n512.npy")

#corr_halohalo_bin1_2048n1024 = np.load(resultsDir + "corr_halohalo_bin1_2048n1024.npy")
corr_halohalo_bin2_2048n1024 = np.load(resultsDir + "corr_halohalo_bin2_2048n1024.npy")

#corr_halohalo_bin1_2048n2048 = np.load(resultsDir + "corr_halohalo_bin1_2048n2048.npy")
corr_halohalo_bin2_2048n2048 = np.load(resultsDir + "corr_halohalo_bin2_2048n2048.npy")

#corr_halohalo_bin1_2048n4096 = np.load(resultsDir + "corr_halohalo_bin1_2048n4096.npy")
corr_halohalo_bin2_2048n4096 = np.load(resultsDir + "corr_halohalo_bin2_2048n4096.npy")




x_values = np.load("/home/alexander/surp2022/SURPProject2022/results/x_values.npy")

corr_voidhalo_total_2048n2048 = np.load("/home/alexander/surp2022/SURPProject2022/results/corrfunc/2048ResTestV1/corr_voidhalo_total_2048n2048.npy")

# %%
plt.figure(figsize=(8,6), dpi=200)


plt.plot(x_values, corr_voidhalo_bin1_2048n512)
plt.plot(x_values, corr_voidhalo_bin2_2048n512)

plt.plot(x_values, corr_voidhalo_bin1_2048n1024)
plt.plot(x_values, corr_voidhalo_bin2_2048n1024)

plt.plot(x_values, corr_voidhalo_bin1_2048n2048)
plt.plot(x_values, corr_voidhalo_bin2_2048n2048)

plt.plot(x_values, corr_voidhalo_bin1_2048n4096)
plt.plot(x_values, corr_voidhalo_bin2_2048n4096)

#plt.plot(x_values, corr_voidhalo_total_2048n2048)

#plt.plot(x_values, corr_voidhalo_bin1_2048n512)

plt.xscale("log")

# %%
plt.figure(figsize=(8,6), dpi=200)


plt.plot(x_values, corr_halohalo_bin2_2048n512, label="512 Resolution")
plt.plot(x_values, corr_halohalo_bin2_2048n1024, label="1024 Resolution")
plt.plot(x_values, corr_halohalo_bin2_2048n2048, label="2048 Resolution")
plt.plot(x_values, corr_halohalo_bin2_2048n4096, label="4096 Resolution")

plt.legend(loc = "upper right")

#plt.plot(x_values, corr_voidhalo_total_2048n2048)

#plt.plot(x_values, corr_voidhalo_bin1_2048n512)

plt.xscale("log")
plt.yscale("log")

# %%
VoidHaloTimes = np.array([43, 158, 185, 200])
HaloHaloBin1Times = np.array([94, 117, 122, 120])
HaloHaloBin2Times = np.array([808, ])

Resolutions = np.array([1,2,3,4])
ResolutionNames = ('512', '1024', '2048', '4096')

plt.figure(figsize=(8,6), dpi = 200)

plt.scatter(Resolutions, HaloHaloBin1Times)

plt.xticks(Resolutions, ResolutionNames)
plt.xlabel("Resolution")
plt.ylabel("seconds")
# Out:
# Text(0, 0.5, 'seconds')
